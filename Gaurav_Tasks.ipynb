# %% [markdown]
# ***Level 1 : Beginner***

# %% [markdown]
# **Task 1**

# %% [markdown]
# Data overview

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-13f46b46-af05-4ee1-be77-158fbd4191b4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-13f46b46-af05-4ee1-be77-158fbd4191b4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
df.shape
# Out:
# (40, 24)

# %%
df.columns
# Out:
# Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source'],
#       dtype='object')

# %%
df.dtypes
# Out:
# gender                               object
# age                                   int64
# Investment_Avenues                   object
# Mutual_Funds                          int64
# Equity_Market                         int64
# Debentures                            int64
# Government_Bonds                      int64
# Fixed_Deposits                        int64
# PPF                                   int64
# Gold                                  int64
# Stock_Marktet                        object
# Factor                               object
# Objective                            object
# Purpose                              object
# Duration                             object
# Invest_Monitor                       object
# Expect                               object
# Avenue                               object
# What are your savings objectives?    object
# Reason_Equity                        object
# Reason_Mutual                        object
# ...

# %%
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...           Duration  \
# 0                 3               7    6     4  ...          1-3 years
# 1                 1               5    6     7  ...  More than 5 years
# 2                 2               5    1     7  ...          3-5 years
# 3                 7               6    4     5  ...   Less than 1 year
# 4                 6               4    5     7  ...   Less than 1 year
#
#   Invest_Monitor   Expect       Avenue What are your savings objectives?  \
# ...

# %%
df.tail()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 35   Male   30                Yes             1              4           6
# 36   Male   30                Yes             2              4           7
# 37   Male   25                Yes             5              4           7
# 38   Male   31                Yes             2              4           7
# 39   Male   29                Yes             4              3           5
#
#     Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Duration  \
# 35                 5               3    2     7  ...  3-5 years
# 36                 5               1    3     6  ...  1-3 years
# 37                 6               1    2     3  ...  3-5 years
# 38                 5               3    1     6  ...  1-3 years
# 39                 7               2    1     6  ...  3-5 years
#
#    Invest_Monitor   Expect                 Avenue  \
# 35        Monthly  20%-30%         Fixed Deposits
# ...

# %%
df[['gender','age']]
# Out:
#     gender  age
# 0   Female   34
# 1   Female   23
# 2     Male   30
# 3     Male   22
# 4   Female   24
# 5   Female   24
# 6   Female   27
# 7     Male   21
# 8     Male   35
# 9     Male   31
# 10  Female   35
# 11    Male   29
# 12  Female   21
# 13  Female   28
# 14  Female   25
# 15    Male   27
# 16  Female   28
# 17    Male   27
# 18    Male   29
# 19    Male   26
# 20    Male   29
# 21  Female   24
# 22    Male   27
# 23    Male   25
# 24  Female   26
# 25  Female   32
# 26    Male   26
# 27    Male   31
# 28    Male   29
# 29  Female   34
# 30    Male   27
# 31  Female   31
# 32    Male   27
# 33    Male   26
# 34    Male   27
# 35    Male   30
# 36    Male   30
# 37    Male   25
# 38    Male   31
# 39    Male   29

# %%
df.describe()
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold
# count       40.000000  40.000000  40.000000
# mean         3.575000   2.025000   5.975000
# std          1.795828   1.609069   1.143263
# min          1.000000   1.000000   2.000000
# 25%          2.750000   1.000000   6.000000
# ...

# %%
df ['age']. value_counts ()
# Out:
# 27    7
# 29    5
# 31    4
# 26    4
# 30    3
# 24    3
# 25    3
# 34    2
# 21    2
# 35    2
# 28    2
# 23    1
# 22    1
# 32    1
# Name: age, dtype: int64

# %% [markdown]
# ***Level 1 : Beginner***

# %% [markdown]
# **TASK 2**

# %% [markdown]
# gender distribution

# %%
df.gender
# Out:
# 0     Female
# 1     Female
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7       Male
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12    Female
# 13    Female
# 14    Female
# 15      Male
# 16    Female
# 17      Male
# 18      Male
# 19      Male
# 20      Male
# 21    Female
# 22      Male
# 23      Male
# 24    Female
# 25    Female
# 26      Male
# 27      Male
# 28      Male
# 29    Female
# 30      Male
# 31    Female
# 32      Male
# 33      Male
# 34      Male
# 35      Male
# 36      Male
# 37      Male
# 38      Male
# 39      Male
# Name: gender, dtype: object

# %%
import matplotlib.pyplot as plt

# %%
gender_counts = df['gender'].value_counts()

# %%
plt.bar(gender_counts.index, gender_counts.values)

plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender Distribution')

plt.show()

# %% [markdown]
# ***Level 2 : Intermediate***

# %% [markdown]
# **TASK 3**

# %% [markdown]
# Descriptive Statistics

# %%
import pandas as pd
import numpy as np

numerical_cols = df.select_dtypes(include=np.number).columns.tolist()

# %%
numerical_cols
# Out:
# ['age',
#  'Mutual_Funds',
#  'Equity_Market',
#  'Debentures',
#  'Government_Bonds',
#  'Fixed_Deposits',
#  'PPF',
#  'Gold']

# %%
df.mean()
# Out:
# <ipython-input-26-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# age                 27.800
# Mutual_Funds         2.550
# Equity_Market        3.475
# Debentures           5.750
# Government_Bonds     4.650
# Fixed_Deposits       3.575
# PPF                  2.025
# Gold                 5.975
# dtype: float64

# %%
df.median()
# Out:
# <ipython-input-27-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# age                 27.0
# Mutual_Funds         2.0
# Equity_Market        4.0
# Debentures           6.5
# Government_Bonds     5.0
# Fixed_Deposits       3.5
# PPF                  1.0
# Gold                 6.0
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-28-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# age                 3.560467
# Mutual_Funds        1.197219
# Equity_Market       1.131994
# Debentures          1.675617
# Government_Bonds    1.369072
# Fixed_Deposits      1.795828
# PPF                 1.609069
# Gold                1.143263
# dtype: float64

# %%
df.min()
# Out:
# gender                                              Female
# age                                                     21
# Investment_Avenues                                      No
# Mutual_Funds                                             1
# Equity_Market                                            1
# Debentures                                               1
# Government_Bonds                                         1
# Fixed_Deposits                                           1
# PPF                                                      1
# Gold                                                     2
# Stock_Marktet                                           No
# Factor                                      Locking Period
# Objective                             Capital Appreciation
# Purpose                                            Returns
# Duration                                         1-3 years
# Invest_Monitor                                       Daily
# ...

# %%
df.max()
# Out:
# gender                                                Male
# age                                                     35
# Investment_Avenues                                     Yes
# Mutual_Funds                                             7
# Equity_Market                                            6
# Debentures                                               7
# Government_Bonds                                         7
# Fixed_Deposits                                           7
# PPF                                                      6
# Gold                                                     7
# Stock_Marktet                                          Yes
# Factor                                                Risk
# Objective                                           Income
# Purpose                                    Wealth Creation
# Duration                                 More than 5 years
# Invest_Monitor                                      Weekly
# ...

# %% [markdown]
# ***Level 2 : Intermediate***

# %% [markdown]
# **TASK 4**

# %% [markdown]
# most prefferred investment Avenue

# %%
df['Investment_Avenues'].value_counts().idxmax()
# Out:
# 'Yes'

# %%
df['Mutual_Funds'].value_counts().idxmax()
# Out:
# 2

# %%
df['Equity_Market'].value_counts(). idxmax()
# Out:
# 4

# %%
df['Debentures'].value_counts(). idxmax()
# Out:
# 7

# %%
df['Government_Bonds'].value_counts(). idxmax()
# Out:
# 5

# %%
df['Fixed_Deposits'].value_counts(). idxmax()
# Out:
# 3

# %%
df['PPF'].value_counts(). idxmax()
# Out:
# 1

# %%
df['Gold'].value_counts(). idxmax()
# Out:
# 6

# %%
investment_avenues = df['Gold']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      5.975000
# std       1.143263
# min       2.000000
# 25%       6.000000
# 50%       6.000000
# 75%       7.000000
# max       7.000000
# Name: Gold, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 6    18
# 7    14
# 5     4
# 4     2
# 2     1
# 3     1
# Name: Gold, dtype: int64

# %%
investment_avenues = df['Mutual_Funds']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      2.550000
# std       1.197219
# min       1.000000
# 25%       2.000000
# 50%       2.000000
# 75%       3.000000
# max       7.000000
# Name: Mutual_Funds, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 2    21
# 3     9
# 1     4
# 4     3
# 5     2
# 7     1
# Name: Mutual_Funds, dtype: int64

# %%
investment_avenues = df['Equity_Market']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      3.475000
# std       1.131994
# min       1.000000
# 25%       3.000000
# 50%       4.000000
# 75%       4.000000
# max       6.000000
# Name: Equity_Market, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 4    16
# 3    12
# 2     5
# 5     3
# 6     2
# 1     2
# Name: Equity_Market, dtype: int64

# %%
investment_avenues = df['Debentures']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      5.750000
# std       1.675617
# min       1.000000
# 25%       5.000000
# 50%       6.500000
# 75%       7.000000
# max       7.000000
# Name: Debentures, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 7    20
# 6     8
# 3     4
# 5     3
# 4     3
# 2     1
# 1     1
# Name: Debentures, dtype: int64

# %%
investment_avenues = df['Government_Bonds']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      4.650000
# std       1.369072
# min       1.000000
# 25%       4.000000
# 50%       5.000000
# 75%       5.000000
# max       7.000000
# Name: Government_Bonds, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 5    18
# 6     7
# 4     7
# 2     4
# 7     2
# 3     1
# 1     1
# Name: Government_Bonds, dtype: int64

# %%
investment_avenues = df['Fixed_Deposits']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      3.575000
# std       1.795828
# min       1.000000
# 25%       2.750000
# 50%       3.500000
# 75%       5.000000
# max       7.000000
# Name: Fixed_Deposits, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 3    10
# 5     8
# 1     8
# 4     7
# 7     3
# 6     2
# 2     2
# Name: Fixed_Deposits, dtype: int64

# %%
investment_avenues = df['PPF']

# %%
summary = investment_avenues.describe()
print(summary)
# Out:
# count    40.000000
# mean      2.025000
# std       1.609069
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       2.250000
# max       6.000000
# Name: PPF, dtype: float64

# %%
frequency = investment_avenues.value_counts()
print(frequency)
# Out:
# 1    24
# 2     6
# 6     3
# 3     3
# 4     2
# 5     2
# Name: PPF, dtype: int64

# %% [markdown]
# ***Level 3 : Advanced***

# %% [markdown]
# **TASK 5**

# %% [markdown]
# Record for investment

# %%
import pandas as pd

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
reasons = df['What are your savings objectives?']

# %%
reasons
# Out:
# 0     Retirement Plan
# 1         Health Care
# 2     Retirement Plan
# 3     Retirement Plan
# 4     Retirement Plan
# 5     Retirement Plan
# 6     Retirement Plan
# 7     Retirement Plan
# 8     Retirement Plan
# 9     Retirement Plan
# 10    Retirement Plan
# 11    Retirement Plan
# 12          Education
# 13    Retirement Plan
# 14        Health Care
# 15        Health Care
# 16        Health Care
# 17    Retirement Plan
# 18    Retirement Plan
# 19        Health Care
# 20    Retirement Plan
# 21        Health Care
# 22    Retirement Plan
# 23        Health Care
# 24    Retirement Plan
# 25    Retirement Plan
# 26    Retirement Plan
# 27        Health Care
# 28    Retirement Plan
# 29    Retirement Plan
# 30          Education
# 31    Retirement Plan
# 32        Health Care
# 33          Education
# 34        Health Care
# 35        Health Care
# 36    Retirement Plan
# 37        Health Care
# 38        Health Care
# 39    Retirement Plan
# ...

# %%
summary = reasons.describe()
print(summary)
# Out:
# count                  40
# unique                  3
# top       Retirement Plan
# freq                   24
# Name: What are your savings objectives?, dtype: object

# %%
frequency = reasons.value_counts()
print(frequency)
# Out:
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64

# %%
reasons = df['Reason_Equity']

# %%
reasons
# Out:
# 0     Capital Appreciation
# 1                 Dividend
# 2     Capital Appreciation
# 3                 Dividend
# 4     Capital Appreciation
# 5                Liquidity
# 6     Capital Appreciation
# 7     Capital Appreciation
# 8     Capital Appreciation
# 9     Capital Appreciation
# 10    Capital Appreciation
# 11    Capital Appreciation
# 12                Dividend
# 13    Capital Appreciation
# 14                Dividend
# 15    Capital Appreciation
# 16    Capital Appreciation
# 17    Capital Appreciation
# 18    Capital Appreciation
# 19    Capital Appreciation
# 20    Capital Appreciation
# 21    Capital Appreciation
# 22    Capital Appreciation
# 23               Liquidity
# 24    Capital Appreciation
# 25    Capital Appreciation
# 26                Dividend
# 27    Capital Appreciation
# 28    Capital Appreciation
# 29    Capital Appreciation
# 30    Capital Appreciation
# 31    Capital Appreciation
# 32    Capital Appreciation
# 33                Dividend
# ...

# %%
summary = reasons.describe()
print(summary)
# Out:
# count                       40
# unique                       3
# top       Capital Appreciation
# freq                        30
# Name: Reason_Equity, dtype: object

# %%
frequency = reasons.value_counts()
print(frequency)
# Out:
# Capital Appreciation    30
# Dividend                 8
# Liquidity                2
# Name: Reason_Equity, dtype: int64

# %%
reasons = df ['Reason_Mutual']

# %%
reasons
# Out:
# 0           Better Returns
# 1           Better Returns
# 2             Tax Benefits
# 3     Fund Diversification
# 4           Better Returns
# 5     Fund Diversification
# 6           Better Returns
# 7           Better Returns
# 8     Fund Diversification
# 9     Fund Diversification
# 10          Better Returns
# 11    Fund Diversification
# 12          Better Returns
# 13    Fund Diversification
# 14          Better Returns
# 15    Fund Diversification
# 16    Fund Diversification
# 17          Better Returns
# 18          Better Returns
# 19    Fund Diversification
# 20          Better Returns
# 21          Better Returns
# 22          Better Returns
# 23          Better Returns
# 24          Better Returns
# 25          Better Returns
# 26    Fund Diversification
# 27    Fund Diversification
# 28          Better Returns
# 29            Tax Benefits
# 30            Tax Benefits
# 31          Better Returns
# 32    Fund Diversification
# 33          Better Returns
# ...

# %%
summary = reasons.describe()
print(summary)
# Out:
# count                 40
# unique                 3
# top       Better Returns
# freq                  24
# Name: Reason_Mutual, dtype: object

# %%
frequency = reasons.value_counts()
print(frequency)
# Out:
# Better Returns          24
# Fund Diversification    13
# Tax Benefits             3
# Name: Reason_Mutual, dtype: int64

# %%
reasons = df ['Reason_Bonds']

# %%
reasons
# Out:
# 0     Safe Investment
# 1     Safe Investment
# 2     Assured Returns
# 3      Tax Incentives
# 4     Safe Investment
# 5     Safe Investment
# 6     Assured Returns
# 7     Assured Returns
# 8     Safe Investment
# 9     Assured Returns
# 10    Assured Returns
# 11    Assured Returns
# 12    Safe Investment
# 13    Assured Returns
# 14    Assured Returns
# 15    Assured Returns
# 16    Assured Returns
# 17    Assured Returns
# 18    Assured Returns
# 19    Assured Returns
# 20    Assured Returns
# 21    Assured Returns
# 22    Assured Returns
# 23    Assured Returns
# 24    Assured Returns
# 25    Assured Returns
# 26    Assured Returns
# 27    Safe Investment
# 28    Assured Returns
# 29    Safe Investment
# 30    Safe Investment
# 31    Assured Returns
# 32    Assured Returns
# 33    Safe Investment
# 34    Safe Investment
# 35    Assured Returns
# 36    Assured Returns
# 37    Safe Investment
# 38    Assured Returns
# 39    Safe Investment
# Name: Reason_Bonds, dtype: object

# %%
summary = reasons.describe()
print(summary)
# Out:
# count                  40
# unique                  3
# top       Assured Returns
# freq                   26
# Name: Reason_Bonds, dtype: object

# %%
frequency = reasons.value_counts()
print(frequency)
# Out:
# Assured Returns    26
# Safe Investment    13
# Tax Incentives      1
# Name: Reason_Bonds, dtype: int64

# %%
reasons = df ['Reason_FD']

# %%
reasons
# Out:
# 0           Fixed Returns
# 1     High Interest Rates
# 2           Fixed Returns
# 3     High Interest Rates
# 4               Risk Free
# 5               Risk Free
# 6     High Interest Rates
# 7               Risk Free
# 8           Fixed Returns
# 9           Fixed Returns
# 10              Risk Free
# 11          Fixed Returns
# 12              Risk Free
# 13              Risk Free
# 14              Risk Free
# 15              Risk Free
# 16              Risk Free
# 17              Risk Free
# 18              Risk Free
# 19              Risk Free
# 20          Fixed Returns
# 21              Risk Free
# 22              Risk Free
# 23              Risk Free
# 24              Risk Free
# 25          Fixed Returns
# 26          Fixed Returns
# 27          Fixed Returns
# 28              Risk Free
# 29          Fixed Returns
# 30          Fixed Returns
# 31          Fixed Returns
# 32          Fixed Returns
# 33              Risk Free
# 34          Fixed Returns
# ...

# %%
summary = reasons.describe()
print(summary)
# Out:
# count            40
# unique            3
# top       Risk Free
# freq             19
# Name: Reason_FD, dtype: object

# %%
frequency = reasons.value_counts()
print(frequency)
# Out:
# Risk Free              19
# Fixed Returns          18
# High Interest Rates     3
# Name: Reason_FD, dtype: int64

# %% [markdown]
# ***Level 3 : Advanced***

# %% [markdown]
# **TASK 6**

# %% [markdown]
# **Savings Objectives**

# %%
savings_objectives = df['What are your savings objectives?']

# %%
savings_objectives
# Out:
# 0     Retirement Plan
# 1         Health Care
# 2     Retirement Plan
# 3     Retirement Plan
# 4     Retirement Plan
# 5     Retirement Plan
# 6     Retirement Plan
# 7     Retirement Plan
# 8     Retirement Plan
# 9     Retirement Plan
# 10    Retirement Plan
# 11    Retirement Plan
# 12          Education
# 13    Retirement Plan
# 14        Health Care
# 15        Health Care
# 16        Health Care
# 17    Retirement Plan
# 18    Retirement Plan
# 19        Health Care
# 20    Retirement Plan
# 21        Health Care
# 22    Retirement Plan
# 23        Health Care
# 24    Retirement Plan
# 25    Retirement Plan
# 26    Retirement Plan
# 27        Health Care
# 28    Retirement Plan
# 29    Retirement Plan
# 30          Education
# 31    Retirement Plan
# 32        Health Care
# 33          Education
# 34        Health Care
# 35        Health Care
# 36    Retirement Plan
# 37        Health Care
# 38        Health Care
# 39    Retirement Plan
# ...

# %%
savings_objectives.describe()
# Out:
# count                  40
# unique                  3
# top       Retirement Plan
# freq                   24
# Name: What are your savings objectives?, dtype: object

# %%
savings_objectives.value_counts()
# Out:
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64

# %% [markdown]
# ***Level 4 : Expert***

# %% [markdown]
# **TASK 7**

# %% [markdown]
# Common information sources

# %%
df.Source
# Out:
# 0     Newspapers and Magazines
# 1        Financial Consultants
# 2                   Television
# 3                     Internet
# 4                     Internet
# 5                     Internet
# 6        Financial Consultants
# 7     Newspapers and Magazines
# 8                   Television
# 9     Newspapers and Magazines
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# 20       Financial Consultants
# 21    Newspapers and Magazines
# 22       Financial Consultants
# 23       Financial Consultants
# 24    Newspapers and Magazines
# 25       Financial Consultants
# 26       Financial Consultants
# 27                  Television
# 28                  Television
# 29    Newspapers and Magazines
# ...

# %%
# Identify the most common sources
common_sources = df['Source']

# %%
print(common_sources)
# Out:
# 0     Newspapers and Magazines
# 1        Financial Consultants
# 2                   Television
# 3                     Internet
# 4                     Internet
# 5                     Internet
# 6        Financial Consultants
# 7     Newspapers and Magazines
# 8                   Television
# 9     Newspapers and Magazines
# 10       Financial Consultants
# 11       Financial Consultants
# 12                    Internet
# 13    Newspapers and Magazines
# 14       Financial Consultants
# 15    Newspapers and Magazines
# 16                  Television
# 17       Financial Consultants
# 18    Newspapers and Magazines
# 19    Newspapers and Magazines
# 20       Financial Consultants
# 21    Newspapers and Magazines
# 22       Financial Consultants
# 23       Financial Consultants
# 24    Newspapers and Magazines
# 25       Financial Consultants
# 26       Financial Consultants
# 27                  Television
# 28                  Television
# 29    Newspapers and Magazines
# ...

# %%
common_sources.describe()
# Out:
# count                        40
# unique                        4
# top       Financial Consultants
# freq                         16
# Name: Source, dtype: object

# %%
common_sources.value_counts()
# Out:
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(10, 6))
plt.bar(common_sources.index, common_sources)
plt.title('Common Sources')
plt.xlabel('Source')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ***Level 4 : Expert***

# %% [markdown]
# **Task 8**

# %% [markdown]
# Investment Duration

# %%
import pandas as pd

# %%
df = pd.read_csv('Data_set 2 - Copy.csv')

# %%
df
# Out:
#     gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0   Female   34                Yes             1              2           5
# 1   Female   23                Yes             4              3           2
# 2     Male   30                Yes             3              6           4
# 3     Male   22                Yes             2              1           3
# 4   Female   24                 No             2              1           3
# 5   Female   24                 No             7              5           4
# 6   Female   27                Yes             3              6           4
# 7     Male   21                Yes             2              3           7
# 8     Male   35                Yes             2              4           7
# 9     Male   31                Yes             1              3           7
# 10  Female   35                Yes             2              4           7
# ...

# %%
df.Duration
# Out:
# 0             1-3 years
# 1     More than 5 years
# 2             3-5 years
# 3      Less than 1 year
# 4      Less than 1 year
# 5             1-3 years
# 6             3-5 years
# 7             3-5 years
# 8             1-3 years
# 9             3-5 years
# 10            3-5 years
# 11            1-3 years
# 12            1-3 years
# 13            1-3 years
# 14            1-3 years
# 15            1-3 years
# 16            1-3 years
# 17            1-3 years
# 18            1-3 years
# 19            3-5 years
# 20            3-5 years
# 21            3-5 years
# 22            3-5 years
# 23            3-5 years
# 24            3-5 years
# 25            3-5 years
# 26            3-5 years
# 27            1-3 years
# 28            1-3 years
# 29            3-5 years
# 30            1-3 years
# 31            3-5 years
# 32            3-5 years
# 33            1-3 years
# 34            1-3 years
# 35            3-5 years
# 36            1-3 years
# 37            3-5 years
# ...

# %%
average_duration = df['Duration']

# %%
average_duration
# Out:
# 0             1-3 years
# 1     More than 5 years
# 2             3-5 years
# 3      Less than 1 year
# 4      Less than 1 year
# 5             1-3 years
# 6             3-5 years
# 7             3-5 years
# 8             1-3 years
# 9             3-5 years
# 10            3-5 years
# 11            1-3 years
# 12            1-3 years
# 13            1-3 years
# 14            1-3 years
# 15            1-3 years
# 16            1-3 years
# 17            1-3 years
# 18            1-3 years
# 19            3-5 years
# 20            3-5 years
# 21            3-5 years
# 22            3-5 years
# 23            3-5 years
# 24            3-5 years
# 25            3-5 years
# 26            3-5 years
# 27            1-3 years
# 28            1-3 years
# 29            3-5 years
# 30            1-3 years
# 31            3-5 years
# 32            3-5 years
# 33            1-3 years
# 34            1-3 years
# 35            3-5 years
# 36            1-3 years
# 37            3-5 years
# ...

# %%
import numpy

Duration= [1-3,3-5,+5,-1]

x = numpy.mean(Duration)

print(x)
# Out:
# 0.0

# %%
#_Average_investment_Duration
numpy . mean(Duration)
# Out:
# 0.0

# %%
max(average_duration)
# Out:
# 'More than 5 years'

# %%
min(average_duration)
# Out:
# '1-3 years'

# %%
average_duration.describe()
# Out:
# count            40
# unique            4
# top       3-5 years
# freq             19
# Name: Duration, dtype: object
